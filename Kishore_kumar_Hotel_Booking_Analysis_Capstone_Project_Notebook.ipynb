# %% [markdown]
# <a href="https://colab.research.google.com/github/karunsri176/Hotel_Booking_Analysis_Capstone_Project/blob/main/Kishore_kumar_Hotel_Booking_Analysis_Capstone_Project_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# # **Hotel Booking Analysis**

# %% [markdown]
# # PART-1 DATA COLLECTION & INSPECTION OF DATASET

# %% [markdown]
# # 1.1) Importing Python Librarys

# %%
#Here Importing python librarys 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #1.2) Mounting the google colab with drive

# %%
#Here google_colab connected with drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1.3) Loading the data set by using path of csv file.

# %%
#Path for dataset
path = '/content/drive/MyDrive/Capstone project -Hotel Booking analysis(EDA)/Hotel Bookings.csv'

# %%
#Loading dataset as dataframe
df = pd.read_csv(path)

# %% [markdown]
# #1.4) Checking head & tail

# %%
#checking head for top 5 rows with features.
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#checking tail for last 5 rows with features.
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# #1.5) Shape of data set

# %%
#shape checking 
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# #1.6) Features names of data set

# %%
#columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# #1.7) Information about dataset

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #1.8) Data Description:
#
# hotel : Hotel(Resort Hotel or City Hotel)
#
# is_canceled : Value indicating if the booking was canceled (1) or not (0)
#
# lead_time : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# arrival_date_year : Year of arrival date
#
# arrival_date_month : Month of arrival date
#
# arrival_date_week_number : Week number of year for arrival date
#
# arrival_date_day_of_month : Day of arrival date
#
# stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# stays_in_week_nights : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# adults : Number of adults
#
# children : Number of children
#
# babies : Number of babies
#
# meal : Type of meal booked. Categories are presented in standard hospitality meal packages:
#
# country : Country of origin.`
#
# market_segment : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# distribution_channel : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# is_repeated_guest : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
#
# reserved_room_type : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# assigned_room_type : Code for the type of room assigned to the booking.
#
# booking_changes : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# deposit_type : Indication on if the customer made a deposit to guarantee the booking.
#
# agent : ID of the travel agency that made the booking
#
# company : ID of the company/entity that made the booking or responsible for paying the booking.
#
# days_in_waiting_list : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# customer_type : Type of booking, assuming one of four categories
#
# adr : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# required_car_parking_spaces : Number of car parking spaces required by the customer
#
# total_of_special_requests : Number of special requests made by the customer (e.g. twin bed or high floor)
#
# reservation_status: Reservation last status, assuming one of three categories
#
# Canceled – booking was canceled by the customer Check-Out – customer has checked in but already departed No-Show – customer did not check-in and did inform the hotel of the reason why
#
# reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# # PART -2 DATA CLEANING & MANIPULATION

# %% [markdown]
# #2.1) Checking & dealing with null values`

# %%
#Here null values checking in percentage format.
print("Null values existing in features")
print("**"*16)
for i in df.columns:
  if round((df[i].isna().sum()/len(df[i]))*100,3)>0.000:
    print(i,":" ,"\t",round((df[i].isna().sum()/len(df[i]))*100,3),"%")
#As per above in company & agent features have 94.307% & 13.686% null value is existing, so need to remove this columns.
# Out:
# Null values existing in features
# ********************************
# children : 	 0.003 %
# country : 	 0.409 %
# agent : 	 13.686 %
# company : 	 94.307 %

# %% [markdown]
# #2.2) Dropping the columns having null values

# %%
df = df.drop(['company','agent'], axis = 1)

# %%
# 'children' & 'country' are two remaining columns which has null values.
# We will rather replace the null values in this columns as number of null values are lesser than previous two columns.
df['country'].fillna(df['country'].mode().to_string(), inplace=True)
df['children'].fillna(round(df['children'].mean()), inplace=True)

# %%
# Deleting rows with empty cells.
df = df.dropna(axis=0)

# %%
# checking for the duplicate rows
df[df.duplicated()].shape
# Out:
# (32020, 30)

# %%
# removing duplicates
df.drop_duplicates(inplace = True)

# %% [markdown]
# #2.3) Again Checking null values if any exist in data set

# %%
#Here null values checking in percentage format.
print("Null values existing in features")
print("**"*16)
for i in df.columns:
  if round((df[i].isna().sum()/len(df[i]))*100,3)>0.000:
    print(i,":" ,"\t",round((df[i].isna().sum()/len(df[i]))*100,3),"%")
# Out:
# Null values existing in features
# ********************************

# %% [markdown]
# #2.4) Merging and creating new columns

# %%
#There are some rows with total number of adults, children or babies equal to zero. So we will remove such rows.
df[df.adults + df.babies + df.children == 0].shape
# Out:
# (166, 30)

# %%
# dropping all 166 those rows in which addtion of of adlults ,children and babies is 0. That simply means  no bookings were made.
df.drop(df[df.adults + df.babies + df.children == 0].index, inplace = True)

# %%
# Creating a new column which will show total number of members.
df['Total_members'] = df['adults'] + df['children'] + df['babies']
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
# Creating a new column which will show total number of night stays.
df['total_night_stays'] = df['stays_in_weekend_nights']+ df['stays_in_week_nights']
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# #2.5) Checking how many continous & discrete variable existing in dataset

# %%
#Checking how many continous & discrete variable existing in dataset
print("Seprating the continous and discrete variables")
print("**"*23)
continous_variables = []
discrete_variables = []
for i in df.columns:
  if len(df[i].unique())>20:
    continous_variables.append(i)
  elif len(df[i].unique())<20:
    discrete_variables.append(i)
print("continous_variables:", len(continous_variables))
print("continous_variables:",continous_variables)
print("***************************"*5)
print("discrete_variables:", len(discrete_variables)) 
print("discrete_variables:",discrete_variables)
# Out:
# Seprating the continous and discrete variables
# **********************************************
# continous_variables: 10
# continous_variables: ['lead_time', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_week_nights', 'country', 'previous_bookings_not_canceled', 'days_in_waiting_list', 'adr', 'reservation_status_date', 'total_night_stays']
# ***************************************************************************************************************************************
# discrete_variables: 22
# discrete_variables: ['hotel', 'is_canceled', 'arrival_date_year', 'arrival_date_month', 'stays_in_weekend_nights', 'adults', 'children', 'babies', 'meal', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'customer_type', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'Total_members']

# %% [markdown]
# #2.6) Checking the Continuous Variable unique elements

# %%
# For Continuous Variable
for i in continous_variables:
  print("********************"*4)
  print(i,":","\t",df[i].unique())
  print("********************"*3)
  print("--------------------"*3)
# Out:
# ********************************************************************************
# lead_time : 	 [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %% [markdown]
# #2.7) Checking the Discrete Variable unique elements

# %%
# For Discrete Variable
for i in discrete_variables:
  print("********************"*3)
  print(i,":","\t",df[i].unique(),"\n ","\n",df[i].value_counts())
  print("********************"*3)
  print("--------------------"*3)
# Out:
# ************************************************************
# hotel : 	 ['Resort Hotel' 'City Hotel']
#
#  City Hotel      53260
# Resort Hotel    33944
# Name: hotel, dtype: int64
# ************************************************************
# ------------------------------------------------------------
# ************************************************************
# is_canceled : 	 [0 1]
#
#  0    63199
# 1    24005
# Name: is_canceled, dtype: int64
# ************************************************************
# ------------------------------------------------------------
# ************************************************************
# arrival_date_year : 	 [2015 2016 2017]
#
#  2016    42303
# 2017    31623
# 2015    13278
# Name: arrival_date_year, dtype: int64
# ************************************************************
# ------------------------------------------------------------
# ************************************************************
# ...

# %% [markdown]
# #2.8) Seprating the Numerical, discrete and target variables

# %%
continous_variables = ['lead_time', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_week_nights', 
                        'booking_changes','days_in_waiting_list', 'adr']


discrete_variables = [ 'is_canceled', 'arrival_date_year', 'arrival_date_month', 'stays_in_weekend_nights', 'adults', 
                      'children', 'babies', 'meal', 'market_segment', 'distribution_channel', 'is_repeated_guest', 
                      'previous_cancellations', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 
                      'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status','country','previous_bookings_not_canceled','reservation_status_date','Total_members','total_night_stays']

target_variable = 'hotel'

# %% [markdown]
# #2.9) Summary of the numerical data

# %%
df.describe() #Here displaying the summery of statistics for each numeric features
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87204.000000  87204.000000       87204.000000
# mean       0.275274     79.980288        2016.210369
# std        0.446655     86.061442           0.686037
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87204.000000               87204.000000
# mean                  26.835306                  15.816258
# std                   13.668830                   8.835616
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# #PART-3 EXPLORATORAY DATA ANALYSIS

# %% [markdown]
# #3.1) Descriptive Analysis

# %% [markdown]
# #3.1.1) Analysis for Continous variable

# %% [markdown]
# #3.1.1.a) Univariate Analysis

# %% [markdown]
# # Histogram

# %%
for i in continous_variables:
  fig = plt.figure(figsize = (20,8))
  sns.histplot(data = df, x = i, kde=True).set_title("Histogram plot for" + " "+ i)
  plt.axvline(df[i].median(), color= "r", ls="--", label ="Median")
  plt.axvline(df[i].mean(), color= "b", ls="--", label = "mean")
  plt.axvline(df[i].mean()-df[i].std(), color= "g", ls= "--", label="-1STD")
  plt.axvline(df[i].mean()+df[i].std(), color= "g", ls = "--", label= "+1STD")
  plt.axvline(df[i].mean()-(2*df[i].std()), color= "magenta", label ="-2STD")
  plt.axvline(df[i].mean()+(2*df[i].std()), color= "magenta", label ="+2STD")
  plt.axvline(df[i].mean()-(3*df[i].std()), color= "cyan", label ="-2STD")
  plt.axvline(df[i].mean()+(3*df[i].std()), color= "cyan", label ="+2STD")
  plt.legend()
  plt.grid()
  plt.show()

  print("Mean" +" "+ "of" + " "+str(i), "\t", ":", round(df[i].mean(),3))
  print("Median"+" "+ "of" + " "+ str(i), "\t", ":", round(df[i].median(),3))
  print("Variance"+" "+ "of" + " "+ str(i), "\t", ":", round(df[i].var(),3))
  print("Standard Deviation"+" "+ "of" + " "+ str(i), "\t", ":", round(df[i].std(),3))
  print("Skew" +" "+ "of" + " "+str(i), "\t", ":", round(df[i].skew(),3))
  print("Kurt"+" "+ "of" + " "+str(i), "\t", ":", round(df[i].kurt(),3))
  print("**"*35)
# Out:
# Mean of lead_time 	 : 79.98
# Median of lead_time 	 : 49.0
# Variance of lead_time 	 : 7406.572
# Standard Deviation of lead_time 	 : 86.061
# Skew of lead_time 	 : 1.431
# Kurt of lead_time 	 : 2.123
# **********************************************************************
# Mean of arrival_date_week_number 	 : 26.835
# Median of arrival_date_week_number 	 : 27.0
# Variance of arrival_date_week_number 	 : 186.837
# Standard Deviation of arrival_date_week_number 	 : 13.669
# Skew of arrival_date_week_number 	 : 0.022
# Kurt of arrival_date_week_number 	 : -0.952
# **********************************************************************
# Mean of arrival_date_day_of_month 	 : 15.816
# Median of arrival_date_day_of_month 	 : 16.0
# Variance of arrival_date_day_of_month 	 : 78.068
# Standard Deviation of arrival_date_day_of_month 	 : 8.836
# Skew of arrival_date_day_of_month 	 : 0.0
# Kurt of arrival_date_day_of_month 	 : -1.196
# ...

# %% [markdown]
# # Box plot

# %%
for i in continous_variables:
  fig = plt.figure(figsize=(20,8))
  sns.boxplot(data=df,x=i).set_title("Boxplot of" +" "+i)
  plt.axvline(df[i].median(),color = "r",ls="--",label="Median")
  plt.axvline(df[i].mean(), color = "b",ls="--", label="Mean")
  plt.axvline(df[i].mean()-df[i].std(), color = "g", ls="--", label = "-1STD")
  plt.axvline(df[i].mean()+df[i].std(), color = "g", ls= "--", label = "+1STD")
  plt.axvline(df[i].mean()-(2*df[i].std()), color = "magenta", label ="-2STD")
  plt.axvline(df[i].mean()+(2*df[i].std()), color = "magenta", label = "+2STD")
  plt.axvline(df[i].mean()-(3*df[i].std()), color = "cyan", label ="-3STD")
  plt.axvline(df[i].mean()+(3*df[i].std()), color = "cyan", label = "+3STD")
  plt.legend(bbox_to_anchor=(1.01,1.02))
  plt.grid()
  plt.grid(True)
  plt.show()

  print("Mean" + " of " + str(i), "\t", ":", round(df[i].mean(),3))
  print("Median" + " of " + str(i), "\t", ":", round(df[i].median(),3))
  print("Standard Deviation" + " of " + str(i), "\t", ":", round(df[i].std(),3))
  print("Q1" + " of " + str(i), "\t", ":", df[i].quantile(0.25)-1.5*(df[i].quantile(0.75)-df[i].quantile(0.25)))
  print("Q2" + " of " + str(i), "\t", ":", round(df[i].quantile(0.25)))
  print("Q3" + " of " + str(i), "\t", ":", round(df[i].quantile(0.50)))
  print("Q4" + " of " + str(i), "\t", ":", round(df[i].quantile(0.75)))
  print("Q5`" + " of " + str(i), "\t", ":",  df[i].quantile(0.75)+1.5*(df[i].quantile(0.75)-df[i].quantile(0.25)))

  print("Kurt" + " of " + str(i), "\t", ":", round(df[i].kurt(),3))
  print("**"*25)
# Out:
# Mean of lead_time 	 : 79.98
# Median of lead_time 	 : 49.0
# Standard Deviation of lead_time 	 : 86.061
# Q1 of lead_time 	 : -160.0
# Q2 of lead_time 	 : 11
# Q3 of lead_time 	 : 49
# Q4 of lead_time 	 : 125
# Q5` of lead_time 	 : 296.0
# Kurt of lead_time 	 : 2.123
# **************************************************
# Mean of arrival_date_week_number 	 : 26.835
# Median of arrival_date_week_number 	 : 27.0
# Standard Deviation of arrival_date_week_number 	 : 13.669
# Q1 of arrival_date_week_number 	 : -15.5
# Q2 of arrival_date_week_number 	 : 16
# Q3 of arrival_date_week_number 	 : 27
# Q4 of arrival_date_week_number 	 : 37
# Q5` of arrival_date_week_number 	 : 68.5
# Kurt of arrival_date_week_number 	 : -0.952
# **************************************************
# Mean of arrival_date_day_of_month 	 : 15.816
# Median of arrival_date_day_of_month 	 : 16.0
# Standard Deviation of arrival_date_day_of_month 	 : 8.836
# Q1 of arrival_date_day_of_month 	 : -14.5
# ...

# %% [markdown]
# #Analysis for Discrete variable
#
# # Univariate Analysis

# %%
for i in discrete_variables:
  fig = plt.figure(figsize=(23,7))
  sns.countplot(data = df, x=i, order=df[i].value_counts().index).set_title("count plot of" +" " +i)
  plt.xticks(rotation=45)
  plt.show()
  print("Mode of"+" "+ str(i), ":","\t",df[i].mode()[0])
  print("**"*80)
# Out:
# Mode of is_canceled : 	 0
# ****************************************************************************************************************************************************************
# Mode of arrival_date_year : 	 2016
# ****************************************************************************************************************************************************************
# Mode of arrival_date_month : 	 August
# ****************************************************************************************************************************************************************
# Mode of stays_in_weekend_nights : 	 0
# ****************************************************************************************************************************************************************
# Mode of adults : 	 2
# ****************************************************************************************************************************************************************
# ...

# %% [markdown]
# # 3.1.1.a) Univariate Analysis

# %% [markdown]
# ## (i) Which type of hotel is mostly prefered by the guests?

# %%
# In order to make it easy to understand about the prefference of hotels we can use data visualisation.
hotel = df['hotel'].value_counts(normalize=True)*100
print("Total both Type of hotel:","\n", hotel)
hotel.plot(kind='pie',colors =['blue','green'],autopct ='%1.1f%%',figsize =(8,8),fontsize= 15,explode =[0.05]*2)
plt.title('Pie chart for hotel type',fontsize = 20)
plt.show()
# The pie chart reveals that 66.4% of the hotels in the dataset are 'City Hotels' and the other 33.6% are 'Resort Hotels'.
# Out:
# Total both Type of hotel:
#  City Hotel      61.07518
# Resort Hotel    38.92482
# Name: hotel, dtype: float64

# %% [markdown]
# # Observation:
#
# ## City Hotel is most preffered hotel by guests. Thus city hotels has maximum bookings.

# %% [markdown]
# ## (ii) What is the pecentage of cancellation in City Hotel?

# %%
# Cancellation percentage of 'City Hotel'.
city_hotel_cancellation = df[df['hotel'] == 'City Hotel']
cancellation_city_hotel = city_hotel_cancellation['is_canceled'].value_counts(normalize=True)*100
print("cancellation_city_hotel:","\n",cancellation_city_hotel)
# Plotting it in pie chart.
cancellation_city_hotel.plot(kind='pie',colors=['skyblue','royalblue'],autopct ='%1.1f%%',figsize =(8,8),fontsize = 15,wedgeprops = {"edgecolor" : "white",
                      'linewidth': 10,
                      'antialiased': True})
plt.title('''CITY HOTEL CANCELLATION STATUS  

(0 = Not cancelled & 1 = Cancelled)''',fontsize = 20)
plt.show()
# Out:
# cancellation_city_hotel:
#  0    69.896733
# 1    30.103267
# Name: is_canceled, dtype: float64

# %% [markdown]
# # Observation :
#
# ## 0= not cancelled
#
# ## 1= cancelled
#
# ## 30.1 % of the bookings were cancelled.

# %% [markdown]
# # (iii) What is the pecentage of cancellation in Resort Hotel?

# %%
# Cancellation percentage of 'Resort Hotel'.
resort_hotel_cancellation = df[df['hotel'] == 'Resort Hotel']
cancellation_resort_hotel = resort_hotel_cancellation['is_canceled'].value_counts(normalize=True)*100
print("cancellation_resort_hotel:",cancellation_resort_hotel)

# Plotting it in pie chart.
cancellation_resort_hotel.plot(kind='pie',colors=['skyblue','royalblue'],autopct ='%1.1f%%',figsize =(8,8),fontsize = 15,wedgeprops = {"edgecolor" : "white",
                      'linewidth': 10,
                      'antialiased': True})
plt.title('''RESORT HOTEL CANCELLATION STATUS  
        
(0 = Not cancelled & 1 = Cancelled)''',fontsize = 20)
plt.show()
# Out:
# cancellation_resort_hotel: 0    76.514259
# 1    23.485741
# Name: is_canceled, dtype: float64

# %% [markdown]
# # Observation :
#
# ## 0= not cancelled
#
# ## 1= cancelled
#
# ## 23.5 % of the bookings were cancelled.

# %% [markdown]
# # Analyzing and Visualizing the ''arrival_date_year'' Features

# %% [markdown]
# # (iv) Which year had the highest bookings?

# %%
# In order to make it easy to understand about most prepared years
arrival_date_year = df['arrival_date_year'].value_counts()
print("Total values of arrival_date_year features:","\n", arrival_date_year)
arrival_date_year.plot(kind='pie',colors =['blue','green','red'],autopct ='%1.1f%%',figsize =(8,8),fontsize= 15)
plt.title('Pie chart for arrival_date_year',fontsize = 20)
plt.show()
# The pie chart reveals that mostly guast was caming in hotel in 2016 is 47.5%, in 2017 is 34.1% and 2015 is 18.4%.
# Out:
# Total values of arrival_date_year features:
#  2016    42303
# 2017    31623
# 2015    13278
# Name: arrival_date_year, dtype: int64

# %%
# Lets visualize the data for most preffered year.
arrival_date_year.plot(kind = 'bar',color ='blue',fontsize = 10,figsize=(11,6))
plt.title('Bar chart for Arrival date year',fontsize = 20)
plt.xlabel('Years',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.grid(True)
plt.show()

# We get to see that in 2016 most hotels were booked followed by 2017 and 2015.

# %% [markdown]
# # Observation:
#
# ## 2016 had the 48.6% higest bookings . 2015 had 15.2% less bookings. overall City hotels had the most of the bookings

# %% [markdown]
# # (v) In which month most of the bookings happened?

# %%
# In order to make it easy to understand about most prepared month in hotels
arrival_date_month = df['arrival_date_month'].value_counts()
print("Total values of arrival_date_month features:","\n", arrival_date_month)
arrival_date_month.plot(kind='pie',colors =['blue','green','red','darkblue','pink','yellow'],autopct ='%1.1f%%',figsize =(8,8),fontsize= 15)
plt.title('Pie chart for arrival_date_month',fontsize = 20)
plt.show()
# Out:
# Total values of arrival_date_month features:
#  August       11239
# July         10039
# May           8342
# April         7898
# June          7755
# March         7487
# October       6921
# September     6680
# February      6080
# December      5110
# November      4970
# January       4683
# Name: arrival_date_month, dtype: int64

# %%
# Lets visualize the data for most preffered month.
arrival_date_month.plot(kind = 'bar',color ='blue',fontsize = 10,figsize=(15,6))
plt.title('Bar chart for Arrival date month',fontsize = 20)
plt.xlabel('Month',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# # Observation:
#
# # July-11.5% and August-12.9% months had the most Bookings. Summer vaccation can be the reason for the bookings.

# %% [markdown]
# # (vi) In which week most of the bookings happened?

# %%
arrival_date_week_number = df['arrival_date_week_number'].value_counts()
print("Total values of arrival_date_week_number features:","\n", arrival_date_week_number)
arrival_date_week_number.plot(kind='pie',colors =['blue','green','red','darkblue','pink','yellow'],autopct ='%1.1f%%',figsize =(20,20),fontsize= 15)
plt.title('Pie chart for arrival_date_week_number',fontsize = 20)
plt.show()
# Out:
# Total values of arrival_date_week_number features:
#  33    2789
# 34    2489
# 32    2445
# 28    2336
# 30    2328
# 31    2285
# 29    2197
# 27    2164
# 35    2098
# 18    2085
# 21    2042
# 15    1986
# 17    1876
# 23    1869
# 20    1839
# 13    1817
# 19    1808
# 25    1784
# 22    1752
# 24    1746
# 16    1735
# 26    1735
# 14    1693
# 41    1659
# 11    1653
# 38    1632
# 36    1625
# 7     1623
# 10    1621
# 43    1605
# 39    1587
# 9     1571
# 12    1567
# 44    1548
# 8     1520
# 37    1470
# 42    1439
# 40    1426
# 53    1418
# 45    1312
# 6     1298
# 47    1281
# 48    1190
# 49    1167
# 46    1137
# 4     1123
# 5     1098
# 52    1053
# 50    1048
# 3     1048
# 2      942
# 1      860
# 51     785
# Name: arrival_date_week_number, dtype: int64

# %%
# Lets visualize the data for most preffered weeks.
arrival_date_week_number.plot(kind = 'bar',color ='blue',fontsize = 10,figsize=(25,6))
plt.title('Bar chart for arrival_date_week_number',fontsize = 20)
plt.xlabel('Weeks',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# # Observation:
#
# ## 33 weeks-3.2% had the most Bookings and 51 week-0.9% had the low Bookings.

# %% [markdown]
# # Analyzing and Visualizing the 'total_night_stays' Features

# %%
# Total count of night stays.
night_stays = df['total_night_stays'].value_counts().sort_values()[0:30]
print(night_stays)

# Visualisation of night stay data till 20 nights.
sns.set(style='whitegrid')
plt.figure(figsize=(12,8))
sns.countplot(x=df['total_night_stays'],palette = 'colorblind')
plt.xlim(0.5,20.5)
plt.title('NIGHT STAYS',fontsize=20)
plt.xlabel('NUMBER OF NIGHTS', fontsize=15)
plt.ylabel('COUNT', fontsize=15)
plt.show()

# Most preffered number of night stays by the guest are 1,2,3,4,5 & 7.
# Out:
# 34      1
# 60      1
# 69      1
# 48      1
# 38      1
# 46      1
# 45      1
# 33      2
# 56      2
# 42      4
# 27      4
# 35      5
# 23      5
# 24      6
# 26      6
# 22     12
# 30     13
# 29     13
# 25     14
# 20     14
# 17     20
# 19     22
# 18     24
# 16     33
# 28     34
# 21     55
# 15     69
# 13    133
# 12    196
# 11    367
# Name: total_night_stays, dtype: int64

# %% [markdown]
# # (vii) Which type of food is mostly preferred by the guests?
#
#
# Types of meal in hotels:
#
# BB - (Bed and Breakfast) HB- (Half Board) FB- (Full Board) SC- (Self Catering)

# %%
# In order to make it easy to understand about most prepared meal
meal = df['meal'].value_counts()
print("Meals prepred:","\n", meal)
print('***'*25)
# Percentage of meal type count.
print("Percentage of meal type:")
percentage_meal_count = df['meal'].value_counts(normalize= True)*100
print(percentage_meal_count)
meal.plot(kind='pie',colors =['blue','green','red','darkblue','pink'],autopct ='%1.1f%%',figsize =(12,9),fontsize= 15)
plt.title('Pie chart for Meals',fontsize = 20)
plt.show()
#Mostly BB 77.03% meals prepared and w r to pie chart.
# Out:
# Meals prepred:
#  BB           67885
# SC            9390
# HB            9078
# Undefined      492
# FB             359
# Name: meal, dtype: int64
# ***************************************************************************
# Percentage of meal type:
# BB           77.846200
# SC           10.767855
# HB           10.410073
# Undefined     0.564194
# FB            0.411678
# Name: meal, dtype: float64

# %%
# Lets visualize the data for most preffered meals.
meal.plot(kind = 'bar',color ='blue',fontsize = 10,figsize=(15,8))
plt.title('Bar chart for meal',fontsize = 20)
plt.xlabel('meal',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# # Observation:
#
# # 1) So the most preferred meal type by the guests is BB( Bed and Breakfast)-77.8%
#
# # 2)HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# # (viii) From which country the most guests are coming?

# %%
# Prefferences of country by customer for hotel booking.
# As there lots of countries in the data so we will only consider top 15
country = df['country'].value_counts().head(15)
print("country:","\n", country)
country.plot(kind='pie',colors =['blue','green','red','darkblue','pink'],autopct ='%1.1f%%',figsize =(12,9),fontsize= 15)
plt.title('Pie chart for country',fontsize = 20)
plt.show()
# Out:
# country:
#  PRT    27342
# GBR    10422
# FRA     8823
# ESP     7242
# DEU     5383
# ITA     3060
# IRL     3015
# BEL     2081
# BRA     1991
# NLD     1910
# USA     1871
# CHE     1566
# CN      1093
# AUT      946
# SWE      833
# Name: country, dtype: int64

# %%
# Lets visualize the data for most preffered weeks.
country.plot(kind = 'bar',color ='blue',fontsize = 10,figsize=(15,7))
plt.title('Bar chart for country',fontsize = 20)
plt.xlabel('country',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# # Observation:
#
# # Most of the guests are coming from portugal i.e more 35.2% guests are from portugal

# %% [markdown]
# # Analyzing and Visualizing the 'market_segment' Features

# %% [markdown]
# # (ix) What type of market segments are available?
#
# Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”

# %%
# Different market segments and their total counts in the dataset.
market_segment_booking = df['market_segment'].value_counts()
print(market_segment_booking)
market_segment_booking.plot(kind = 'bar',color ='blue',fontsize = 10,figsize=(15,7))
plt.title('MARKET SEGMENT',fontsize = 20)
plt.ylabel('COUNT',fontsize = 15)
plt.xlabel('UNIQUE MARKET SEGMENTS',fontsize = 15)
plt.grid(True)
plt.show()
# Out:
# Online TA        51544
# Offline TA/TO    13847
# Direct           11778
# Groups            4921
# Corporate         4194
# Complementary      692
# Aviation           226
# Undefined            2
# Name: market_segment, dtype: int64

# %% [markdown]
# # Observation:
#
# # As per above Mostly Online TA(Travel Agents) market segmentation available-51544.

# %% [markdown]
# # (x) What is the Percentage of repeated guests?

# %%
# Count of repeated and non-repeated guest.(0 = Not repeated & 1 = Repeated)
print('is_repeated_guest:')
print(df['is_repeated_guest'].value_counts(normalize= True)*100)

# Visualisation.
plt.figure(figsize=(8,8))
sns.countplot(data = df, x = 'is_repeated_guest',palette='rocket')
plt.title('''REPEATED & NON REPEATED GUEST

(0 = Not repeated & 1 = Repeated)''',fontsize=20)
plt.show()

# It shows that most of the guests do not repeat their bookings.
# Out:
# is_repeated_guest:
# 0    96.142379
# 1     3.857621
# Name: is_repeated_guest, dtype: float64

# %% [markdown]
# # Observation:
#
# ## 3364 people are repeaated guests. The retention guest rate is very low.

# %% [markdown]
# ## (xi)What is the percentage distribution of required_car_parking_spaces?

# %%
df['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=20,labels=None)

labels=df['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces',fontweight ='bold', size =20)
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.show()

# %%
# Car parking requirement count.
car_parking = df['required_car_parking_spaces'].value_counts()
print('Car parking:')
print(car_parking)

# Visualisation.
car_parking.plot(kind='line',color='y',linestyle=':',linewidth=5,figsize =(12,6))
plt.title('CAR PARKING SPACE ANALYSIS',fontsize = 20)
plt.ylabel('COUNT',fontsize = 15)
plt.xlabel('NUMBER OF PARKING SPACE',fontsize = 15)
plt.grid(True)
plt.show()
# Out:
# Car parking:
# 0    79898
# 1     7273
# 2       28
# 3        3
# 8        2
# Name: required_car_parking_spaces, dtype: int64

# %% [markdown]
# # Observation:
#
# # 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# #(xii) What is the percentage distribution of "Customer Type"?

# %%
df['customer_type'].value_counts().plot.pie(explode=[0.05]*4,shadow=True,autopct='%1.1f%%',figsize=(12,8),fontsize=20,labels=None)


labels= df['customer_type'].value_counts().index.tolist()
plt.title('% Distribution of Customer Type',fontweight ='bold', size =20)
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.show()

# %% [markdown]
# # Observation:
#
# # Transient customer type is more which is 82.4 %. percentage of Booking associated by the Group is vey low.

# %% [markdown]
# # (xiii)Which is the most preferred room type by the customers?

# %%
#set plotsize
plt.figure(figsize=(15,7))

#plotting 
sns.countplot(x=df['assigned_room_type'],order=df['assigned_room_type'].value_counts().index)
#  set xlabel for the plot
plt.xlabel('Room Type')
# set y label for the plot
plt.ylabel('Count of Room Type')
#set title for the plot
plt.title("Most preferred Room type",fontweight ='bold', size =20)
plt.show()

# %% [markdown]
# # Observation:
#
# ## So the most preferred Room type is "A".

# %% [markdown]
# # 3.1.1.b)  Bivariate analysis

# %% [markdown]
# ## (i) Which type of hotel is mostly guests comes in a year or booking in a year?

# %%
# Yearly booking of hotels.
yearly_hotel_booked = df.groupby(['arrival_date_year','hotel'])['hotel'].count().unstack()
print(yearly_hotel_booked)
print('***'*30)
# Plotting the data to make it more easy to understand.
yearly_hotel_booked.plot(kind ='barh',color= ['blue','gray'],fontsize =12,figsize=(12,6))
plt.title('Yearly booking of hotels',fontsize = 20)
plt.xlabel('Number of bookings',fontsize = 15)
plt.ylabel('Year',fontsize = 15)
plt.grid(True)
plt.show()

# From this visualisation its clear that most hotel bookings took place in '2016' and in each year 'City Hotel' was most preffered.
# Out:
# hotel              City Hotel  Resort Hotel
# arrival_date_year
# 2015                     6526          6752
# 2016                    26677         15626
# 2017                    20057         11566
# ******************************************************************************************

# %% [markdown]
# # Observation:
#
# ## In 2016 year mostly guest cames/ booking done(city hotel-26677 and Resort hotel-15626) as compared to Resort hotel.

# %% [markdown]
# # (ii) Which type of hotel is mostly guests comes in a month or books in a month?

# %%
# Monthly booking of hotels.
yearly_hotel_booked = df.groupby(['arrival_date_month','hotel'])['hotel'].count().unstack()
print(yearly_hotel_booked)
print('***'*40)
# Plotting the data to make it more easy to understand.
yearly_hotel_booked.plot(kind ='bar',color= ['blue','gray'],fontsize =12,figsize=(15,8))
plt.title('Montly booking of hotels',fontsize = 20)
plt.xlabel('Months',fontsize = 15)
plt.ylabel('Number of bookings',fontsize = 15)
plt.grid(True)
plt.show()

# Via this visualisation we can clearly observe that 'City Hotel' is booked more than the 'Resort Hotel' in each and every month.
# Out:
# hotel               City Hotel  Resort Hotel
# arrival_date_month
# April                     5070          2828
# August                    6575          4664
# December                  2998          2112
# February                  3590          2490
# January                   2724          1959
# July                      5727          4312
# June                      4996          2759
# March                     4831          2656
# May                       5400          2942
# November                  2922          2048
# October                   4197          2724
# September                 4230          2450
# ************************************************************************************************************************

# %% [markdown]
# ## Observation:
#
# # July and August months had the most Bookings. Summer vaccation can be the reason for the bookings.

# %% [markdown]
# ## (iii) Which type of hotel has highest booking cancellation?

# %%
# Cancellation data of hotels(0 = Not cancelled & 1 = Cancelled)
booking_cancelled = df.groupby(['hotel','is_canceled'])['is_canceled'].count().unstack()
print(booking_cancelled) 
print('***'*30)

# Visualising cancellation data.
booking_cancelled.plot(kind='bar',figsize=(11,6),color=['blue','gray'],fontsize=13)
plt.title('''CANCELLATION STATUS

(0 = Not cancelled & 1 = Cancelled)''',fontsize = 20)
plt.xlabel('HOTEL',fontsize = 15)
plt.ylabel('COUNT',fontsize = 15)
plt.grid(True)
plt.show()
# Out:
# is_canceled       0      1
# hotel
# City Hotel    37227  16033
# Resort Hotel  25972   7972
# ******************************************************************************************

# %% [markdown]
# # Obsevation:
#
# ## City hotel has 37227 of booking cancellation

# %% [markdown]
# ## (iv) Which Hotel type has the highest ADR?

# %%
# Average ADR of different types of hotel.
avg_hotel_adr = df.groupby(['hotel'])['adr'].mean()
print(avg_hotel_adr)

# Visualisation.
avg_hotel_adr.plot(kind='bar', figsize=(10,7),color=['blue','brown'])
plt.title('Avarage adr of hotel type',fontsize = 20)
plt.ylabel('Hotel type',fontsize = 15)
plt.xlabel('Avrage adr',fontsize = 15)
plt.show()
# Out:
# hotel
# City Hotel      111.274295
# Resort Hotel     99.070541
# Name: adr, dtype: float64

# %% [markdown]
# # Observation:
#
# # City hotel has the highest ADR. That means city hotels are generating more revenues than the resort hotels. More the ADR more is the revenue.

# %% [markdown]
# # (v) Which country has the highest ADR?

# %%
# Countries with best 'adr'.
# Considering top 10 countries.
country_adr = df.groupby(['country'])['adr'].mean().sort_values(ascending = False)[0:10]
print(country_adr)

# Visualisation.
country_adr.plot(kind='bar', figsize=(14,6),color='brown',width=0.8)
plt.title('Adr of top 10 countries',fontsize=20)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Adr',fontsize=15)
plt.show()

#Dji is the highest adr.
# Out:
# country
# DJI    273.000000
# AIA    265.000000
# AND    202.652857
# UMI    200.000000
# LAO    181.665000
# MYT    177.750000
# NCL    175.500000
# GIB    169.082667
# FRO    165.666667
# COM    165.305000
# Name: adr, dtype: float64

# %% [markdown]
# # Observation:
#
# # DJI has the highest ADR. More the ADR more is the revenue.

# %% [markdown]
# # (Vi) Which year & month has the highest ADR?

# %%
# Average ADR of different months and year.
adr_month_year= df.groupby(['arrival_date_month','arrival_date_year'])['adr'].mean()
adr_month_year
# Out:
# arrival_date_month  arrival_date_year
# April               2016                  91.005056
#                     2017                 115.267292
# August              2015                 123.288033
#                     2016                 149.047291
#                     2017                 168.608016
# December            2015                  71.797801
#                     2016                  88.025536
# February            2016                  70.083367
#                     2017                  78.953285
# January             2016                  62.718858
#                     2017                  75.043030
# July                2015                 112.533828
#                     2016                 131.664914
#                     2017                 147.709722
# June                2016                 108.930888
#                     2017                 128.929366
# March               2016                  79.586620
# ...

# %%
# Visualisation.
line,ax = plt.subplots(figsize=(18,5)) 
sns.lineplot(x='arrival_date_month',y='adr',data=df,hue='arrival_date_year',style='arrival_date_year',markers=True,palette='dark',linewidth=3)
ax.set_title('AVERAGE ADR OF MONTH & YEAR', fontsize=20)
ax.set_xlabel('MONTH',fontsize=15)
ax.set_ylabel('ADR',fontsize=15)
plt.grid(True)
plt.show()

# As per graph its seen that hotel business is scaling up each and every year.

# %% [markdown]
# # Observation:
#
# # The highest ADR as mention below. More the ADR more is the revenue.
#
# # Month-    August
#
# # year
#
# # 2015      123.288033
#
# # 2016      149.047291
#
# ## 2017      168.608016

# %% [markdown]
# # (vii) Which Hotels has the most repeated guests?

# %%
# repeated guest=1
#not repeated guest=0
repeated_guests_df= df[df['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repated_guests'})
#set plot size adn plot barplot
plt.figure(figsize=(10,8))
sns.barplot(x=repeated_guests_df['hotel'],y=repeated_guests_df['number_of_repated_guests'])
# set labels
plt.xlabel('Hotel type',fontsize=18)
plt.ylabel('count of repeated guests',fontsize=18)
plt.title("Most repeated guests for each hotel",fontsize=20)
plt.show()

# %% [markdown]
# # Observation: Resort Hotel has slightly more repeated guests than the City Hotels. It is almost similar for both hotels.

# %% [markdown]
# # 3.1.1.c) Multivariate Analysis

# %% [markdown]
# # i) Which Market Segment has the highest cancellation rate?

# %%
market_segment_df= df[df['is_canceled']==1]   # canceled=1
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   # group by
print(market_segment_df)
#set plotsize and plot barchart
plt.figure(figsize=(15,7))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)
# set labels
plt.xlabel('market_segment',fontsize=18)
plt.ylabel('Counts',fontsize=18)
plt.title('Cancellation Rate Vs market_segment',fontsize=20)
plt.show()
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      54
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     263
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     887
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1256
# 10  Offline TA/TO  Resort Hotel     798
# 11      Online TA    City Hotel   12614
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %% [markdown]
# # Observation:
#
# # 'Online T/A' has the highest cancellation in both type of cities
#
# # In order to reduce the booking cancellations hotels need to set the refundable/ no refundable and deposit policies policies

# %% [markdown]
# # ii) ADR across different market segment?

# %%
Groupby= df.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()   # group by
# set plot size and plto barchart
plt.figure(figsize=(15,7))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=Groupby.sort_values(by='adr',ascending=False))
plt.title('Adr across market segment')
plt.show()

# %% [markdown]
# # Obseravtion:
#
# 'Direct' and 'Online TA' are contributing the most in both types of hotels.
#
# Aviation segment should focus on increasing the bookings of 'City Hotel'

# %% [markdown]
# # 3.1.1.d) Correlation Analysis

# %%
plt.figure(figsize=(20,15),dpi=125)
sns.heatmap(df.corr(), cmap= 'coolwarm' ,annot=True);
plt.show()

# %% [markdown]
# # Observation in correlation analysis:
#
# 1) is_canceled and same_room_alloted_or_not are negatively corelated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
#
# 2) lead_time and total_stay is positively corelated.That means more is the stay of cutsomer more will be the lead time.
#
# 3) adults,childrens and babies are corelated to each other. That means more the people more will be adr.
#
# 4) is_repeated guest and previous bookings not canceled has strong corelation. may be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# # CONCLUSION :-
#
# (1) 'City hotels' and 'Resort hotels' are two types of hotels present in the dataset, out of which, 'City hotels'are more preffered by the customers than the latter. (61.1% customer prefers 'City hotels' whereas 38.9% customer prefers 'Resort hotels').
#
# (2) Dataset contains booking data of 3 different years(2017,2016,2015), out of which, maximum hotel bookings took place in 2016 & 2015 witnessed the least number of hotel bookings.
#
# (3) Out of all months, 'August' witnessed highest number of hotel bookings whereas 'January' witnessed the least.
#
# (4) Among all the countries in the dataset, PRT(Portugal) has got the maximum number of hotel bookings.
#
# (5) Its observed that 'City hotels' was more cancelled as compared to 'Resort   hotels'.
#
# (6) Coming to the analysis of market segment, 'Online TA' brings maximum       bookings.
#
# (7)The value of ADR of hotels is approximately 111.10.
#
# (8) Average ADR of 'City hotels' is more than that of 'Resort hotels'.
#   'DJI' has the highest average ADR among all countries.
#
# (9) Considering all the three years, 'August' has got the highest average ADR in each year.
#
# (10) Its observed that average ADR is incrementing every year from 2015 to 2017, which clearly states that hotel business is scaling up every year.
#
# (11) After analysing the meal data, its found that 77.84% of customers prefers BB(Bread & Breakfast).
#
# (12) Most of the hotels have 0 to 1 car parking space.
#
# etc...

# %% [markdown]
# # **Thank you!**
